# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv' )

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=['Oldpeak' , 'ST_Slope'] , axis= 1, inplace=True)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  HeartDisease
# 0              N             0
# 1              N             1
# 2              N             0
# 3              Y             1
# 4              N             0

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10 , 6))
sns.barplot(x='HeartDisease', y='Age', data=df)
plt.title("Average Age vs Heart Disease")
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'HeartDisease'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#        HeartDisease
# count    918.000000
# mean       0.553377
# std        0.497414
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
plt.figure(figsize=(18, 10))

def plotting(var, num):
    plt.subplot(2, 3, num)
    sns.histplot(df[var], kde=True, bins='auto')
    plt.title(var, fontsize=14)

plotting('Age', 1)
plotting('FastingBS', 2)
plotting('MaxHR', 3)
plotting('RestingBP', 4)
plotting('Cholesterol', 5)
plotting('HeartDisease', 6)

plt.tight_layout(pad=3)
plt.show()

# %%
#changing thr value of restingBP and Cholesterol
BP_mean = df.loc[df['RestingBP'] != 0, 'RestingBP'].mean()
print(BP_mean)
# Out:
# 132.54089422028352

# %%
df['RestingBP'] = df['RestingBP'].replace(0 , BP_mean)
df['RestingBP'] = df['RestingBP'].round(2)

# %%
ch_mean = df.loc[df['Cholesterol'] != 0 , 'Cholesterol'].mean()
print(ch_mean)
# Out:
# 244.6353887399464

# %%
df['Cholesterol'] = df['Cholesterol'].replace(0 , ch_mean)
df['Cholesterol'] = df['Cholesterol'].round(2)

# %%
#checking by smae plotting
plt.figure(figsize=(18, 10))

def plotting(var, num):
    plt.subplot(2, 3, num)
    sns.histplot(df[var], kde=True, bins='auto')
    plt.title(var, fontsize=14)

plotting('Age', 1)
plotting('FastingBS', 2)
plotting('MaxHR', 3)
plotting('RestingBP', 4)
plotting('Cholesterol', 5)
plotting('HeartDisease', 6)

plt.tight_layout(pad=3)
plt.savefig('sub_plot.png' , dpi = 300 , bbox_inches = 'tight')
plt.show()

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA      140.0        289.0          0     Normal    172
# 1   49   F           NAP      160.0        180.0          0     Normal    156
# 2   37   M           ATA      130.0        283.0          0         ST     98
# 3   48   F           ASY      138.0        214.0          0     Normal    108
# 4   54   M           NAP      150.0        195.0          0     Normal    122
#
#   ExerciseAngina  HeartDisease
# 0              N             0
# 1              N             1
# 2              N             0
# 3              Y             1
# 4              N             0

# %%
#graph on based sex
plt.figure(figsize= (10 , 5))
sns.countplot(x = 'Sex' , data = df , hue= 'ChestPainType')
plt.show()

# %%
#graph on based sex
plt.figure(figsize= (10 , 5))
sns.countplot(x = 'Sex' , data = df , hue= 'HeartDisease')
plt.show()

# %%
df['ChestPainType'].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
#pic chat of ChestPainType
counts = df['ChestPainType'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(counts, 
        labels=counts.index, 
        autopct='%.1f%%', 
        shadow=True, 
        explode=[0.1 , 0.2 , 0.1 , 0.2])

plt.title('Distribution of ChestPainType')
plt.show()

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA      140.0        289.0          0     Normal    172
# 1   49   F           NAP      160.0        180.0          0     Normal    156
# 2   37   M           ATA      130.0        283.0          0         ST     98
# 3   48   F           ASY      138.0        214.0          0     Normal    108
# 4   54   M           NAP      150.0        195.0          0     Normal    122
#
#   ExerciseAngina  HeartDisease
# 0              N             0
# 1              N             1
# 2              N             0
# 3              Y             1
# 4              N             0

# %%
df['RestingECG'].value_counts()
# Out:
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64

# %%
##pic chat of RestingECG
counts = df['RestingECG'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(counts, 
        labels=counts.index, 
        autopct='%.1f%%', 
        shadow=True, 
        explode=[0.1 , 0.2 , 0.1])

plt.title('Distribution of RestingECG')
plt.show()

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.540893   244.636253    0.233115  136.809368
# std      9.432617   17.989932    53.318029    0.423046   25.460334
# min     28.000000   80.000000    85.000000    0.000000   60.000000
# 25%     47.000000  120.000000   214.000000    0.000000  120.000000
# 50%     54.000000  130.000000   244.640000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#        HeartDisease
# count    918.000000
# mean       0.553377
# std        0.497414
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
#heat map 
plt.figure(figsize=(10 , 5))
col = ['Age', 'RestingBP', 'Cholesterol', 'FastingBS',
       'MaxHR', 'HeartDisease']

v = sns.heatmap(
    df[col].corr(),
    annot=True,
    cmap='BuPu',
    annot_kws={'fontsize': 12, 'color': 'green'},
    linewidths=2,
    linecolor='black',
    xticklabels=True,
    yticklabels=True
)

v.set(title='Correlation Heatmap')

plt.show()

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA      140.0        289.0          0     Normal    172
# 1   49   F           NAP      160.0        180.0          0     Normal    156
# 2   37   M           ATA      130.0        283.0          0         ST     98
# 3   48   F           ASY      138.0        214.0          0     Normal    108
# 4   54   M           NAP      150.0        195.0          0     Normal    122
#
#   ExerciseAngina  HeartDisease
# 0              N             0
# 1              N             1
# 2              N             0
# 3              Y             1
# 4              N             0

# %%
#label encoding and on-hot encoding
#LB-> sex , FastingBS ,ExerciseAngina
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df['Sex'] = le.fit_transform(df['Sex'])
df['RestingECG'] = le.fit_transform(df['RestingECG'])
df['ExerciseAngina'] = le.fit_transform(df['ExerciseAngina'])

#on Hot Encoding 0n -> ChestPainType
df = pd.get_dummies(df, columns=['ChestPainType'], drop_first=True)

# %%
df.head(10)
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0   40    1      140.0        289.0          0           1    172
# 1   49    0      160.0        180.0          0           1    156
# 2   37    1      130.0        283.0          0           2     98
# 3   48    0      138.0        214.0          0           1    108
# 4   54    1      150.0        195.0          0           1    122
# 5   39    1      120.0        339.0          0           1    170
# 6   45    0      130.0        237.0          0           1    170
# 7   54    1      110.0        208.0          0           1    142
# 8   37    1      140.0        207.0          0           1    130
# 9   48    0      120.0        284.0          0           1    120
#
#    ExerciseAngina  HeartDisease  ChestPainType_ATA  ChestPainType_NAP  \
# 0               0             0               True              False
# 1               0             1              False               True
# 2               0             0               True              False
# 3               1             1              False              False
# 4               0             0              False               True
# 5               0             0              False               True
# 6               0             0               True              False
# 7               0             0               True              False
# 8               1             1              False              False
# 9               0             0               True              False
#
#    ChestPainType_TA
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7             False
# 8             False
# 9             False

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG',
#        'MaxHR', 'ExerciseAngina', 'HeartDisease', 'ChestPainType_ATA',
#        'ChestPainType_NAP', 'ChestPainType_TA'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                918 non-null    int64
#  1   Sex                918 non-null    int64
#  2   RestingBP          918 non-null    float64
#  3   Cholesterol        918 non-null    float64
#  4   FastingBS          918 non-null    int64
#  5   RestingECG         918 non-null    int64
#  6   MaxHR              918 non-null    int64
#  7   ExerciseAngina     918 non-null    int64
#  8   HeartDisease       918 non-null    int64
#  9   ChestPainType_ATA  918 non-null    bool
#  10  ChestPainType_NAP  918 non-null    bool
#  11  ChestPainType_TA   918 non-null    bool
# dtypes: bool(3), float64(2), int64(7)
# memory usage: 67.4 KB

# %%
#train and test the model
from sklearn.model_selection import train_test_split

x = df[['Age', 'Sex', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG',
        'MaxHR', 'ExerciseAngina', 'ChestPainType_ATA',
        'ChestPainType_NAP', 'ChestPainType_TA']]

y = df['HeartDisease']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, shuffle=True)

# %%
#Standard Scaling 
#SS -> RestingBP   , CholesterolMaxHR  , RestingECG , MaxHR	
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
df.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0   40    1      140.0        289.0          0           1    172
# 1   49    0      160.0        180.0          0           1    156
# 2   37    1      130.0        283.0          0           2     98
# 3   48    0      138.0        214.0          0           1    108
# 4   54    1      150.0        195.0          0           1    122
#
#    ExerciseAngina  HeartDisease  ChestPainType_ATA  ChestPainType_NAP  \
# 0               0             0               True              False
# 1               0             1              False               True
# 2               0             0               True              False
# 3               1             1              False              False
# 4               0             0              False               True
#
#    ChestPainType_TA
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
#logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score , precision_score , recall_score , f1_score
model = LogisticRegression()
model.fit(x_train , y_train)
L_pred = model.predict(x_test)
print('Logistic Prediction : ' ,  L_pred[:5])

# for i , val in enumerate(L_pred):
#     if val == 0:
#         print(f"patient{i}: Safe")
#     else:
#         print(f"patient{i}: Not Safe")

for i, (pred, actual) in enumerate(zip(L_pred, y_test), start=1):
    print(f"Patient {i} -> Predicted: {pred}, Actual: {actual}")
# Out:
# Logistic Prediction :  [0 0 1 1 0]
# Patient 1 -> Predicted: 0, Actual: 0
# Patient 2 -> Predicted: 0, Actual: 1
# Patient 3 -> Predicted: 1, Actual: 1
# Patient 4 -> Predicted: 1, Actual: 1
# Patient 5 -> Predicted: 0, Actual: 0
# Patient 6 -> Predicted: 1, Actual: 1
# Patient 7 -> Predicted: 0, Actual: 1
# Patient 8 -> Predicted: 0, Actual: 0
# Patient 9 -> Predicted: 0, Actual: 1
# Patient 10 -> Predicted: 1, Actual: 1
# Patient 11 -> Predicted: 0, Actual: 0
# Patient 12 -> Predicted: 1, Actual: 0
# Patient 13 -> Predicted: 0, Actual: 0
# Patient 14 -> Predicted: 0, Actual: 0
# Patient 15 -> Predicted: 1, Actual: 1
# Patient 16 -> Predicted: 1, Actual: 1
# Patient 17 -> Predicted: 0, Actual: 0
# Patient 18 -> Predicted: 1, Actual: 1
# Patient 19 -> Predicted: 0, Actual: 1
# Patient 20 -> Predicted: 0, Actual: 0
# Patient 21 -> Predicted: 1, Actual: 1
# Patient 22 -> Predicted: 1, Actual: 0
# Patient 23 -> Predicted: 0, Actual: 0
# Patient 24 -> Predicted: 1, Actual: 0
# Patient 25 -> Predicted: 1, Actual: 1
# Patient 26 -> Predicted: 1, Actual: 1
# Patient 27 -> Predicted: 0, Actual: 0
# Patient 28 -> Predicted: 1, Actual: 1
# Patient 29 -> Predicted: 0, Actual: 0
# Patient 30 -> Predicted: 0, Actual: 0
# Patient 31 -> Predicted: 0, Actual: 1
# Patient 32 -> Predicted: 0, Actual: 1
# Patient 33 -> Predicted: 1, Actual: 0
# Patient 34 -> Predicted: 1, Actual: 1
# Patient 35 -> Predicted: 1, Actual: 1
# Patient 36 -> Predicted: 0, Actual: 0
# Patient 37 -> Predicted: 1, Actual: 1
# Patient 38 -> Predicted: 0, Actual: 0
# Patient 39 -> Predicted: 1, Actual: 1
# Patient 40 -> Predicted: 0, Actual: 1
# Patient 41 -> Predicted: 1, Actual: 1
# Patient 42 -> Predicted: 0, Actual: 1
# Patient 43 -> Predicted: 0, Actual: 1
# Patient 44 -> Predicted: 0, Actual: 0
# Patient 45 -> Predicted: 0, Actual: 0
# Patient 46 -> Predicted: 0, Actual: 0
# Patient 47 -> Predicted: 1, Actual: 1
# Patient 48 -> Predicted: 1, Actual: 1
# Patient 49 -> Predicted: 1, Actual: 1
# Patient 50 -> Predicted: 1, Actual: 0
# Patient 51 -> Predicted: 0, Actual: 1
# Patient 52 -> Predicted: 0, Actual: 0
# Patient 53 -> Predicted: 1, Actual: 1
# Patient 54 -> Predicted: 1, Actual: 1
# Patient 55 -> Predicted: 1, Actual: 1
# Patient 56 -> Predicted: 1, Actual: 0
# Patient 57 -> Predicted: 0, Actual: 0
# Patient 58 -> Predicted: 1, Actual: 1
# Patient 59 -> Predicted: 1, Actual: 1
# Patient 60 -> Predicted: 1, Actual: 1
# Patient 61 -> Predicted: 0, Actual: 0
# Patient 62 -> Predicted: 0, Actual: 0
# Patient 63 -> Predicted: 0, Actual: 0
# Patient 64 -> Predicted: 1, Actual: 1
# Patient 65 -> Predicted: 0, Actual: 0
# Patient 66 -> Predicted: 1, Actual: 1
# Patient 67 -> Predicted: 1, Actual: 1
# Patient 68 -> Predicted: 1, Actual: 1
# Patient 69 -> Predicted: 1, Actual: 1
# Patient 70 -> Predicted: 0, Actual: 1
# Patient 71 -> Predicted: 1, Actual: 0
# Patient 72 -> Predicted: 0, Actual: 0
# Patient 73 -> Predicted: 1, Actual: 1
# Patient 74 -> Predicted: 0, Actual: 1
# Patient 75 -> Predicted: 0, Actual: 0
# Patient 76 -> Predicted: 1, Actual: 1
# Patient 77 -> Predicted: 1, Actual: 0
# Patient 78 -> Predicted: 0, Actual: 1
# Patient 79 -> Predicted: 0, Actual: 0
# Patient 80 -> Predicted: 1, Actual: 1
# Patient 81 -> Predicted: 1, Actual: 1
# Patient 82 -> Predicted: 1, Actual: 1
# Patient 83 -> Predicted: 1, Actual: 1
# Patient 84 -> Predicted: 0, Actual: 0
# Patient 85 -> Predicted: 1, Actual: 1
# Patient 86 -> Predicted: 0, Actual: 1
# Patient 87 -> Predicted: 0, Actual: 0
# Patient 88 -> Predicted: 1, Actual: 1
# Patient 89 -> Predicted: 0, Actual: 0
# Patient 90 -> Predicted: 0, Actual: 0
# Patient 91 -> Predicted: 0, Actual: 1
# Patient 92 -> Predicted: 1, Actual: 1
# Patient 93 -> Predicted: 1, Actual: 1
# Patient 94 -> Predicted: 0, Actual: 0
# Patient 95 -> Predicted: 0, Actual: 0
# Patient 96 -> Predicted: 0, Actual: 0
# Patient 97 -> Predicted: 1, Actual: 1
# Patient 98 -> Predicted: 0, Actual: 0
# Patient 99 -> Predicted: 1, Actual: 1
# Patient 100 -> Predicted: 1, Actual: 1
# Patient 101 -> Predicted: 0, Actual: 0
# Patient 102 -> Predicted: 1, Actual: 1
# Patient 103 -> Predicted: 1, Actual: 1
# Patient 104 -> Predicted: 0, Actual: 0
# Patient 105 -> Predicted: 1, Actual: 1
# Patient 106 -> Predicted: 1, Actual: 1
# Patient 107 -> Predicted: 0, Actual: 0
# Patient 108 -> Predicted: 1, Actual: 1
# Patient 109 -> Predicted: 1, Actual: 1
# Patient 110 -> Predicted: 1, Actual: 0
# Patient 111 -> Predicted: 1, Actual: 1
# Patient 112 -> Predicted: 1, Actual: 1
# Patient 113 -> Predicted: 0, Actual: 0
# Patient 114 -> Predicted: 0, Actual: 1
# Patient 115 -> Predicted: 1, Actual: 1
# Patient 116 -> Predicted: 0, Actual: 0
# Patient 117 -> Predicted: 1, Actual: 1
# Patient 118 -> Predicted: 0, Actual: 0
# Patient 119 -> Predicted: 1, Actual: 1
# Patient 120 -> Predicted: 0, Actual: 0
# Patient 121 -> Predicted: 1, Actual: 1
# Patient 122 -> Predicted: 1, Actual: 1
# Patient 123 -> Predicted: 1, Actual: 1
# Patient 124 -> Predicted: 1, Actual: 1
# Patient 125 -> Predicted: 0, Actual: 0
# Patient 126 -> Predicted: 0, Actual: 0
# Patient 127 -> Predicted: 0, Actual: 0
# Patient 128 -> Predicted: 0, Actual: 1
# Patient 129 -> Predicted: 0, Actual: 0
# Patient 130 -> Predicted: 1, Actual: 1
# Patient 131 -> Predicted: 0, Actual: 0
# Patient 132 -> Predicted: 1, Actual: 1
# Patient 133 -> Predicted: 1, Actual: 1
# Patient 134 -> Predicted: 1, Actual: 1
# Patient 135 -> Predicted: 1, Actual: 1
# Patient 136 -> Predicted: 0, Actual: 0
# Patient 137 -> Predicted: 1, Actual: 1
# Patient 138 -> Predicted: 0, Actual: 1
# Patient 139 -> Predicted: 0, Actual: 0
# Patient 140 -> Predicted: 1, Actual: 1
# Patient 141 -> Predicted: 1, Actual: 0
# Patient 142 -> Predicted: 0, Actual: 0
# Patient 143 -> Predicted: 1, Actual: 1
# Patient 144 -> Predicted: 1, Actual: 1
# Patient 145 -> Predicted: 1, Actual: 1
# Patient 146 -> Predicted: 1, Actual: 0
# Patient 147 -> Predicted: 0, Actual: 1
# Patient 148 -> Predicted: 0, Actual: 0
# Patient 149 -> Predicted: 1, Actual: 0
# Patient 150 -> Predicted: 1, Actual: 1
# Patient 151 -> Predicted: 0, Actual: 0
# Patient 152 -> Predicted: 1, Actual: 1
# Patient 153 -> Predicted: 1, Actual: 1
# Patient 154 -> Predicted: 0, Actual: 0
# Patient 155 -> Predicted: 0, Actual: 1
# Patient 156 -> Predicted: 0, Actual: 0
# Patient 157 -> Predicted: 0, Actual: 1
# Patient 158 -> Predicted: 0, Actual: 0
# Patient 159 -> Predicted: 0, Actual: 0
# Patient 160 -> Predicted: 1, Actual: 1
# Patient 161 -> Predicted: 0, Actual: 0
# Patient 162 -> Predicted: 0, Actual: 0
# Patient 163 -> Predicted: 1, Actual: 1
# Patient 164 -> Predicted: 0, Actual: 0
# Patient 165 -> Predicted: 1, Actual: 1
# Patient 166 -> Predicted: 1, Actual: 1
# Patient 167 -> Predicted: 1, Actual: 1
# Patient 168 -> Predicted: 1, Actual: 1
# Patient 169 -> Predicted: 0, Actual: 0
# Patient 170 -> Predicted: 0, Actual: 0
# Patient 171 -> Predicted: 1, Actual: 1
# Patient 172 -> Predicted: 1, Actual: 1
# Patient 173 -> Predicted: 0, Actual: 0
# Patient 174 -> Predicted: 1, Actual: 0
# Patient 175 -> Predicted: 0, Actual: 0
# Patient 176 -> Predicted: 1, Actual: 1
# Patient 177 -> Predicted: 1, Actual: 1
# Patient 178 -> Predicted: 1, Actual: 1
# Patient 179 -> Predicted: 0, Actual: 0
# Patient 180 -> Predicted: 0, Actual: 1
# Patient 181 -> Predicted: 1, Actual: 1
# Patient 182 -> Predicted: 1, Actual: 1
# Patient 183 -> Predicted: 0, Actual: 0
# Patient 184 -> Predicted: 1, Actual: 1

# %%
#find matrices 
from sklearn.metrics import accuracy_score , precision_score , recall_score , f1_score
acc = accuracy_score(y_test , L_pred)
print('Accuracy Score : ' , round(acc , 2))

pre = precision_score(y_test , L_pred)
print('Precision Score : ' , round(pre , 2))

re = recall_score(y_test , L_pred)
print('Recall Score : ' ,round(re , 2))

f1 = f1_score(y_test , L_pred)
print('F1 Score : ' , round(f1 , 2) )
# Out:
# Accuracy Score :  0.81
# Precision Score :  0.87
# Recall Score :  0.79
# F1 Score :  0.83

# %%
#Another Model test -> RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
modelr = RandomForestClassifier()
modelr.fit(x_train , y_train)
R_pred = modelr.predict(x_test)

print('Forest Predicated : ' , R_pred[:5])

for i ,(pred , actual) in enumerate(zip(R_pred , y_test) , start = 1):
    print(f"Patient {i} -> Predict:  {pred}  , Actual:  {actual}")
# Out:
# Forest Predicated :  [0 0 1 1 0]
# Patient 1 -> Predict:  0  , Actual:  0
# Patient 2 -> Predict:  0  , Actual:  1
# Patient 3 -> Predict:  1  , Actual:  1
# Patient 4 -> Predict:  1  , Actual:  1
# Patient 5 -> Predict:  0  , Actual:  0
# Patient 6 -> Predict:  1  , Actual:  1
# Patient 7 -> Predict:  1  , Actual:  1
# Patient 8 -> Predict:  1  , Actual:  0
# Patient 9 -> Predict:  0  , Actual:  1
# Patient 10 -> Predict:  1  , Actual:  1
# Patient 139 -> Predict:  0  , Actual:  0
# Patient 140 -> Predict:  1  , Actual:  1
# Patient 141 -> Predict:  0  , Actual:  0
# Patient 142 -> Predict:  0  , Actual:  0
# Patient 143 -> Predict:  1  , Actual:  1
# Patient 144 -> Predict:  1  , Actual:  1
# Patient 145 -> Predict:  1  , Actual:  1
# Patient 146 -> Predict:  1  , Actual:  0
# Patient 147 -> Predict:  0  , Actual:  1
# Patient 148 -> Predict:  0  , Actual:  0
# Patient 149 -> Predict:  1  , Actual:  0
# Patient 150 -> Predict:  1  , Actual:  1
# Patient 151 -> Predict:  0  , Actual:  0
# Patient 152 -> Predict:  1  , Actual:  1
# Patient 153 -> Predict:  1  , Actual:  1
# Patient 154 -> Predict:  0  , Actual:  0
# Patient 155 -> Predict:  0  , Actual:  1
# Patient 156 -> Predict:  0  , Actual:  0
# Patient 157 -> Predict:  0  , Actual:  1
# Patient 158 -> Predict:  0  , Actual:  0
# Patient 159 -> Predict:  0  , Actual:  0
# Patient 160 -> Predict:  1  , Actual:  1
# Patient 161 -> Predict:  0  , Actual:  0
# Patient 162 -> Predict:  0  , Actual:  0
# Patient 163 -> Predict:  1  , Actual:  1
# Patient 164 -> Predict:  0  , Actual:  0
# Patient 165 -> Predict:  1  , Actual:  1
# Patient 166 -> Predict:  1  , Actual:  1
# Patient 167 -> Predict:  1  , Actual:  1
# Patient 168 -> Predict:  1  , Actual:  1
# Patient 169 -> Predict:  0  , Actual:  0
# Patient 170 -> Predict:  1  , Actual:  0
# Patient 171 -> Predict:  1  , Actual:  1
# Patient 172 -> Predict:  1  , Actual:  1
# Patient 173 -> Predict:  0  , Actual:  0
# Patient 174 -> Predict:  1  , Actual:  0
# Patient 175 -> Predict:  0  , Actual:  0
# Patient 176 -> Predict:  1  , Actual:  1
# Patient 177 -> Predict:  1  , Actual:  1
# Patient 178 -> Predict:  1  , Actual:  1
# Patient 179 -> Predict:  0  , Actual:  0
# Patient 180 -> Predict:  1  , Actual:  1
# Patient 181 -> Predict:  1  , Actual:  1
# Patient 182 -> Predict:  1  , Actual:  1
# Patient 183 -> Predict:  0  , Actual:  0
# Patient 184 -> Predict:  1  , Actual:  1

# %%
#find matrices  of RandomForestClassifier
from sklearn.metrics import accuracy_score , precision_score , recall_score , f1_score
acc = accuracy_score(y_test , R_pred)
print('Accuracy Score : ' , round(acc , 2))

pre = precision_score(y_test , R_pred)
print('Precision Score : ' , round(pre , 2))

re = recall_score(y_test , R_pred)
print('Recall Score : ' ,round(re , 2))

f1 = f1_score(y_test , R_pred)
print('F1 Score : ' , round(f1 , 2) )
# Out:
# Accuracy Score :  0.78
# Precision Score :  0.83
# Recall Score :  0.79
# F1 Score :  0.81

# %%
# Another ModeL -> XGBclassifier
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit
#find matrices  of XGBclassifier
from sklearn.metrics import accuracy_score , precision_score , recall_score , f1_score
acc = accuracy_score(y_test , X_pred)
print('Accuracy Score : ' , round(acc , 2))

pre = precision_score(y_test , X_pred)
print('Precision Score : ' , round(pre , 2))

re = recall_score(y_test , X_pred)
print('Recall Score : ' ,round(re , 2))

f1 = f1_score(y_test , X_pred)
print('F1 Score : ' , round(f1 , 2) )
# Out:
# Accuracy Score :  0.77
# Precision Score :  0.81
# Recall Score :  0.79
# F1 Score :  0.8

# %%
# finding all algorithum of accuarcy score
print("Logistic:", accuracy_score(y_test, L_pred))
print("Random Forest:", accuracy_score(y_test, R_pred))
print("XGBoost:", accuracy_score(y_test, X_pred))
# Out:
# Logistic: 0.8097826086956522
# Random Forest: 0.7934782608695652
# XGBoost: 0.7717391304347826

# %%
#graph b\w accuracy score 
models = ['Logistic', 'Random Forest', 'XGBoost']
accuracy = [0.81, 0.79, 0.77]

plt.bar(models, accuracy)
plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy")
plt.show()

# %%
#finnding classificaton_report of all the algorithum 
from sklearn.metrics import classification_report
print('Classification Report of Logistic : \n', classification_report(y_test , L_pred))
print('Classification Report of Random Forest: \n', classification_report(y_test , R_pred))
print('Classification Report of XGBoost : \n', classification_report(y_test , X_pred))
# Out:
# Classification Report of Logistic :
#                precision    recall  f1-score   support
#
#            0       0.74      0.83      0.79        77
#            1       0.87      0.79      0.83       107
#
#     accuracy                           0.81       184
#    macro avg       0.81      0.81      0.81       184
# weighted avg       0.82      0.81      0.81       184
#
# Classification Report of Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        77
#            1       0.82      0.82      0.82       107
#
#     accuracy                           0.79       184
#    macro avg       0.79      0.79      0.79       184
# weighted avg       0.79      0.79      0.79       184
#
# Classification Report of XGBoost :
#                precision    recall  f1-score   support
#
#            0       0.72      0.74      0.73        77
#            1       0.81      0.79      0.80       107
#
#     accuracy                           0.77       184
#    macro avg       0.77      0.77      0.77       184
# weighted avg       0.77      0.77      0.77       184

# %%
#confusion matrix ao all alogorithum
from sklearn.metrics import confusion_matrix

cmL = confusion_matrix(y_test , L_pred)
cmR = confusion_matrix(y_test , R_pred)
cmX = confusion_matrix(y_test , X_pred)

print('Confusion of Logistic : \n' , cmL)
print('Confusion of Forest : \n' , cmR)
print('Confusion of XGBoost : \n' , cmX)
# Out:
# Confusion of Logistic :
#  [[64 13]
#  [22 85]]
# Confusion of Forest :
#  [[58 19]
#  [19 88]]
# Confusion of XGBoost :
#  [[57 20]
#  [22 85]]

# %%
#heat map of all confusion matrix of all alorithums
plt.figure(figsize=(18, 6))

def plotting_heat(cm, title, num):
    plt.subplot(1, 3, num)
    sns.heatmap(cm, 
                annot=True, 
                fmt='d', 
                cmap='Blues',
                xticklabels=['No Disease', 'Disease'],
                yticklabels=['No Disease', 'Disease'])
    
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')

plotting_heat(cmL, 'Logistic Regression', 1)
plotting_heat(cmR, 'Random Forest', 2)
plotting_heat(cmX, 'XGBoost', 3)

plt.tight_layout()
plt.show()

# %%
#roc of random foreset
from sklearn.metrics import roc_curve, auc

y_prob = modelr.predict_proba(x_test)[:,1]

fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')
plt.plot([0,1],[0,1],'--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
